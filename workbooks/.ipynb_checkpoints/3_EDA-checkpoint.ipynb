# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
lyric_df = pd.read_csv('../data/lyrics_clean.csv', index_col = 0)

# %%
lyric_df.head(2)
# Out:
#    song_rank   artist_name             song_title  year  \
# 0          1  Glenn Miller  Chattanooga Choo Choo  1941
# 1          2    Sammy Kaye                  Daddy  1941
#
#                                               lyrics  decade  word_count  \
# 0  pardon me, boy is that the chattanooga choo ch...    1940         151
# 1  ladada ladada da dada ladada ladada da dada la...    1940         201
#
#    characters  word_length                                       clean_lyrics  \
# 0         806          5.3  pardon boy chattanooga choo choo track twenty ...
# 1        1021          5.1  ladada ladada da dada ladada ladada da dada la...
#
#    profanity  suggestive
# 0      False           0
# 1       True           1

# %% [markdown]
# ## Average Word & Character Count Per Decade

# %%
lyric_df.groupby('decade')['word_count'].mean().plot(kind = 'bar', figsize = (7,7))
plt.title('Word Count Has Increased Significantly Over Time', size = 25)
plt.ylabel('Word Count', size = 20)
plt.xlabel('Decade', size = 20)
plt.yticks(size = 15)
plt.xticks(rotation = .25, size = 15);

# %%
lyric_df.groupby('decade')['word_length'].mean().plot(kind = 'bar', figsize = (7,7))
plt.title('Average Word Length Has Stayed Largely Stable', size = 25)
plt.ylabel('Average Word Length', size = 20)
plt.xlabel('Decade', size = 20)
plt.yticks(size = 15)
plt.xticks(rotation = .25, size = 15)
plt.axhline(y=4.7, color='r', linestyle='-', label = 'Average Length of English Words'), 
plt.legend(bbox_to_anchor=(1.04,0.5), loc="center left", borderaxespad=0, labels = ['English Average', 'Word Length']);

# %% [markdown]
# # Sentiment Analysis

# %%
def sentiment_score(lyrics):
 
    # Create a SentimentIntensityAnalyzer object.
    sia_obj = SentimentIntensityAnalyzer()
 
    # polarity_scores method of SentimentIntensityAnalyzer
    # object gives a sentiment dictionary.
    # which contains pos, neg, neu, and compound scores.
    sentiment_dict = sia_obj.polarity_scores(lyrics)
 
    return sentiment_dict['compound']

# %%
lyric_df['lyric_valence'] = lyric_df['clean_lyrics'].map(sentiment_score)

# %%
lyric_df['is_positive'] = np.where(lyric_df['lyric_valence'] >= .5, 1, 0)
lyric_df['is_negative'] = np.where(lyric_df['lyric_valence'] < -.5 , 1, 0)
lyric_df['is_neutral'] = np.where((lyric_df['lyric_valence'] >= -.5) & (lyric_df['lyric_valence'] <=.5), 1, 0)

# %%
lyric_df.to_csv('../data/lyrics_final.csv')
lyric_df
# Out:
#       song_rank                           artist_name  \
# 0             1                          Glenn Miller
# 1             2                            Sammy Kaye
# 2             3                            Artie Shaw
# 3             4                   The Andrews Sisters
# 5             6                          Jimmy Dorsey
# ...         ...                                   ...
# 6299         96  Schoolboy Q feat. BJ The Chicago Kid
# 6300         97                                 Drake
# 6301         98                             Lee Brice
# 6302         99  Miranda Lambert and Carrie Underwood
# 6303        100                           Miley Cyrus
#
#                    song_title  year  \
# 0       Chattanooga Choo Choo  1941
# 1                       Daddy  1941
# 2                    Stardust  1941
# 3     Boogie Woogie Bugle Boy  1941
# 5                  Green Eyes  1941
# ...                       ...   ...
# 6299                   Studio  2014
# 6300  0 To 100 / The Catch Up  2014
# 6301            I Don’t Dance  2014
# 6302            Somethin’ Bad  2014
# 6303                Adore You  2014
#
#                                                  lyrics  decade  word_count  \
# 0     pardon me, boy is that the chattanooga choo ch...    1940         151
# 1     ladada ladada da dada ladada ladada da dada la...    1940         201
# 2     and now the purple dusk of twilight time steal...    1940         153
# 3     he was a famous trumpet man from out chicago w...    1940         316
# 5      well, green eyes with their soft lights your ...    1940         186
# ...                                                 ...     ...         ...
# 6299     i'm just sittin' in the studio just tryna g...    2010         520
# 6300     fuck bein' on some chill shit we go 0 to 10...    2010         954
# 6301   i’ll never settle down that’s what i always t...    2010         207
# 6302   stand on the bar, stomp your feet, start clap...    2010         307
# 6303   oh-oh, hey, oh-oh   baby, baby, yeah, are you...    2010         221
#
#       characters  word_length  \
# 0            806          5.3
# 1           1021          5.1
# 2            783          5.1
# 3           1582          5.0
# 5            933          5.0
# ...          ...          ...
# 6299        2585          5.0
# 6300        4790          5.0
# 6301        1024          4.9
# 6302        1670          5.4
# 6303        1027          4.6
#
#                                            clean_lyrics  profanity  \
# 0     pardon boy chattanooga choo choo track twenty ...      False
# 1     ladada ladada da dada ladada ladada da dada la...       True
# 2     purple dusk twilight time steal across meadow ...      False
# 3     famous trumpet man chicago way boogie style on...      False
# 5     well green eye soft light eye promise sweet ni...      False
# ...                                                 ...        ...
# 6299  i'm sittin' studio tryna get baby song fuckin'...       True
# 6300  fuck bein' chill shit go 0 100 nigga real quic...       True
# 6301  never settle always thought yeah kind man ask ...      False
# 6302  stand bar stomp foot start clapping got real g...      False
# 6303  oh oh hey oh oh baby baby yeah listening wonde...       True
#
#       suggestive  lyric_valence  is_positive  is_negative  is_neutral
# 0              0         0.8979            1            0           0
# 1              1         0.9957            1            0           0
# 2              0         0.9584            1            0           0
# 3              0         0.9796            1            0           0
# 5              0         0.9961            1            0           0
# ...          ...            ...          ...          ...         ...
# 6299           1         0.9758            1            0           0
# 6300           1        -0.9974            0            1           0
# 6301           0         0.9918            1            0           0
# 6302           0        -0.2500            0            0           1
# 6303           1         0.9966            1            0           0
#
# [5369 rows x 16 columns]

# %%
lyric_df.groupby('decade')['lyric_valence'].mean().plot(kind = 'bar', figsize = (7,7));

# %%
lyric_df.groupby('year')['lyric_valence'].mean().plot(kind = 'bar', figsize = (17,10));

# %%
plt.figure(figsize = (10,10))
sns.boxplot(x = lyric_df['decade'], y = lyric_df['lyric_valence']);

# %%
lyric_df.sort_values(by = 'lyric_valence', ascending = True)
# Out:
#       song_rank                   artist_name  \
# 3662         59               Michael Jackson
# 4592         89             Junior M.A.F.I.A.
# 6216         13                  Taylor Swift
# 3561         58                 Janet Jackson
# 5815         12  T.I. feat. Justin Timberlake
# ...         ...                           ...
# 2563         60                       Tavares
# 4440         37                        Brandy
# 3867         64                   Karyn White
# 3458         55                         Sting
# 3579         76                       Madonna
#
#                               song_title  year  \
# 3662                                 Bad  1987
# 4592                           Get Money  1996
# 6216                        Shake It Off  2014
# 3561                               Nasty  1986
# 5815                       Dead And Gone  2009
# ...                                  ...   ...
# 2563     Heaven Must Be Missing An Angel  1976
# 4440                                Baby  1995
# 3867                 The Way You Love Me  1989
# 3458  If You Love Somebody Set Them Free  1985
# 3579                           True Blue  1986
#
#                                                  lyrics  decade  word_count  \
# 3662   your butt is mine, gon' tell you right, ah ju...    1980         550
# 4592   fuck bitches, get money (what?) fuck niggas, ...    1990         674
# 6216   i stay out too late got nothing in my brain t...    2010         593
# 3561   gimme a beat   sittin' in the movie show, thi...    1980         288
# 5815   ayy, let me kick it to you right quick, man n...    2000         900
# ...                                                 ...     ...         ...
# 2563  heaven must be missing an angel missing one an...    1970         469
# 4440   oh, yeah   baby, baby, baby, baby don't 'cha ...    1990         563
# 3867   hey, baby you're driving me crazy with that s...    1980         622
# 3458   free free set them free (oh) free free set th...    1980         397
# 3579   hey what? listen   i've had other guys, i've ...    1980         450
#
#       characters  word_length  \
# 3662        2796          5.1
# 4592        3620          5.4
# 6216        2956          5.0
# 3561        1507          5.2
# 5815        4473          5.0
# ...          ...          ...
# 2563        2640          5.6
# 4440        3235          5.7
# 3867        2832          4.5
# 3458        2023          5.1
# 3579        2292          5.1
#
#                                            clean_lyrics  profanity  \
# 3662  butt mine gon' tell right ah show face broad d...       True
# 4592  fuck bitch get money fuck nigga get money fuck...       True
# 6216  stay late got nothing brain that's people say ...       True
# 3561  gimme beat sittin' movie show thinkin' nasty t...       True
# 5815  ayy let kick right quick man gangsta shit man ...       True
# ...                                                 ...        ...
# 2563  heaven must missing angel missing one angel ch...      False
# 4440  oh yeah baby baby baby baby 'cha know fine hey...      False
# 3867  hey baby driving crazy special loving feeling ...      False
# 3458  free free set free oh free free set free free ...      False
# 3579  hey listen i've guy i've looked eye never knew...      False
#
#       suggestive  lyric_valence  is_positive  is_negative  is_neutral
# 3662           1        -0.9998            0            1           0
# 4592           1        -0.9998            0            1           0
# 6216           1        -0.9995            0            1           0
# 3561           1        -0.9993            0            1           0
# 5815           1        -0.9993            0            1           0
# ...          ...            ...          ...          ...         ...
# 2563           0         0.9999            1            0           0
# 4440           0         0.9999            1            0           0
# 3867           0         0.9999            1            0           0
# 3458           0         0.9999            1            0           0
# 3579           0         0.9999            1            0           0
#
# [5369 rows x 16 columns]

# %%
sentiment = lyric_df[['decade', 'is_negative', 'is_neutral', 'is_positive']].groupby('decade').mean().reset_index()
sentiment.rename(columns = {'decade': 'Decade', 'is_negative': 'Negative', 'is_positive': 'Positive', 'is_neutral': 'Neutral'}, inplace = True)
sentiment
# Out:
#    Decade  Negative   Neutral  Positive
# 0    1940  0.120219  0.098361  0.781421
# 1    1950  0.076419  0.054585  0.868996
# 2    1960  0.120133  0.081201  0.798665
# 3    1970  0.121212  0.071429  0.807359
# 4    1980  0.119372  0.074346  0.806283
# 5    1990  0.144391  0.048926  0.806683
# 6    2000  0.193590  0.039744  0.766667
# 7    2010  0.153614  0.051205  0.795181

# %%
sentiment.set_index('Decade').plot(kind='bar', stacked=True, color=['darkred', 'gray', 'darkgreen'], figsize = (12,8))
plt.style.use('fivethirtyeight')
plt.xlabel('Decade', size = 30)
plt.ylabel('Percentage', size = 30)
plt.ylim(top = .8)
plt.xticks(rotation = .25, size = 20)
plt.yticks(ticks = [0, .2, .4, .6, .8, 1], labels = ['0%', '20%', '40%', '60%', '80%', '100%'], size = 20)
plt.legend(fontsize = 20, framealpha = 1, shadow = True)
plt.title('Pop Songs Are Overwhelmingly Positive', fontsize = 35, fontstyle = 'italic')
plt.show();

# %%
sentiment.set_index('Decade').plot(kind='bar', stacked=True, color=['darkred', 'gray', 'darkgreen'], figsize = (12,8))
plt.xlabel('Decade', size = 30)
plt.ylabel('Percentage', size = 30)
plt.ylim(top = .4)
plt.xticks(rotation = .25, size = 20)
plt.yticks(ticks = [0, .2, .4], labels = ['0%', '20%', '40%'], size = 20)
plt.legend(fontsize = 20, framealpha = 1, shadow = True)
plt.title('Zooming In', fontsize = 35, fontstyle = 'italic')
plt.show();

# %% [markdown]
# ## Profane / Suggestive Analysis

# %% [markdown]
# An analysis of how many songs are considered profane or suggestive. Songs fall into this category if they contain words that are profanity, slurs or sexually suggestive. A full list of the 835 words checked for this status can be found here: https://github.com/snguyenthanh/better_profanity/blob/master/better_profanity/profanity_wordlist.txt

# %%
lyric_df.groupby('decade')['suggestive'].mean().plot(kind = 'bar', figsize = (7,7))
plt.title('Over Half of Songs After 2000 Are Suggestive or Profane', size = 25)
plt.ylabel('% Suggestive', size = 20)
plt.xlabel('Decade', size = 20)
plt.yticks(size = 15)
plt.xticks(rotation = .25, size = 15);
