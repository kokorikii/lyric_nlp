# %%
# importing modules
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, ExtraTreesClassifier, VotingClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction import text
from sklearn.compose import make_column_transformer, make_column_selector
import re
import nltk
import eli5

# setting pandas settings to display additional rows within Jupyter Labs
pd.set_option('display.max_rows', 500)

# %%
# importing clean Reddit CSV 
lyric_df = pd.read_csv('../data/lyrics_final.csv')

# %%
# adding a category_id column to encode decades
lyric_df['category_id'] = lyric_df['decade'].factorize()[0]
lyric_df.head(2)
# Out:
#    Unnamed: 0  song_rank   artist_name             song_title  year  \
# 0           0          1  Glenn Miller  Chattanooga Choo Choo  1941
# 1           1          2    Sammy Kaye                  Daddy  1941
#
#                                               lyrics  decade  word_count  \
# 0  pardon me, boy is that the chattanooga choo ch...    1940         151
# 1  ladada ladada da dada ladada ladada da dada la...    1940         201
#
#    characters  word_length                                       clean_lyrics  \
# 0         806          5.3  pardon boy chattanooga choo choo track twenty ...
# 1        1021          5.1  ladada ladada da dada ladada ladada da dada la...
#
#    profanity  suggestive  lyric_valence  is_positive  is_negative  is_neutral  \
# 0      False           0         0.8979            1            0           0
# 1       True           1         0.9957            1            0           0
#
#    category_id
# 0            0
# 1            0

# %%
# creating X from the cleaned Reddit post titles
X = lyric_df[['clean_lyrics', 'word_count', 'is_negative','suggestive']]

# %%
X.shape
# Out:
# (5369, 4)

# %%
y = lyric_df['category_id']

# %%
y.shape
# Out:
# (5369,)

# %%
# train test split with random state
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=48, stratify = y)

# %% [markdown]
# ## Baseline Model

# %% [markdown]
# Baseline accuracy is 17.79%, the equivalent of choosing the most common decade (the 1980s).

# %%
lyric_df['decade'].value_counts(normalize = True)
# Out:
# 1980    0.177873
# 1970    0.172099
# 1960    0.167443
# 1990    0.156081
# 2000    0.145278
# 1950    0.085305
# 2010    0.061836
# 1940    0.034085
# Name: decade, dtype: float64

# %% [markdown]
# ## Attempt #1 - Naive Bayes

# %%
# creating pipe with naive bayes and countvectorizer
ct1 = make_column_transformer(
    (CountVectorizer(stop_words = 'english', max_features = 1000), 'clean_lyrics'),
    remainder='passthrough',
    verbose_feature_names_out = False)

bayes_pipe = make_pipeline(ct1, StandardScaler(with_mean = False), MultinomialNB())

# gridsearching across ngram ranges
params = {'multinomialnb__alpha': [.25, .5, .75, 1, 1.25]}

# creating gridsearch and fitting to training data
bayes_grid = GridSearchCV(bayes_pipe, params, n_jobs =-1)
bayes_grid.fit(X_train,y_train)

# %%
# creating predictions for test data
preds = bayes_grid.predict(X_test)

# %%
# accuracy score for test data
bayes_grid.score(X_test, y_test)
# Out:
# 0.3425167535368578

# %%
# accuracy score for training data
bayes_grid.score(X_train, y_train)
# Out:
# 0.583705911574764

# %%
# pulling best parameters from gridsearch
bayes_grid.best_params_
# Out:
# {'multinomialnb__alpha': 0.25}

# %% [markdown]
# ## Attempt 2 - Logistic Regression

# %%
# creating pipe with logistic regression and countvectorizer
ct1 = make_column_transformer(
    (CountVectorizer(stop_words = 'english', max_features = 1000), 'clean_lyrics'),
    remainder='passthrough',
    verbose_feature_names_out = False)

logreg_pipe = make_pipeline(ct1, StandardScaler(with_mean = False), LogisticRegression(random_state = 48))

# gridsearching across ngram ranges
params = {'logisticregression__C': [.25, .5, .75, 1], 'logisticregression__max_iter': [20_000]}

# creating gridsearch and fitting to training data
logreg_grid = GridSearchCV(logreg_pipe, params, n_jobs =-1)
logreg_grid.fit(X_train,y_train)

# %%
# creating predictions from training data
preds = logreg_grid.predict(X_test)

# %%
# accuracy score on test set
logreg_grid.score(X_test, y_test)
# Out:
# 0.31347728965003724

# %%
# accuracy score on training set
logreg_grid.score(X_train, y_train)
# Out:
# 0.9083457526080477

# %%
# pulling best parameters from gridsearch
logreg_grid.best_params_
# Out:
# {'logisticregression__C': 0.25, 'logisticregression__max_iter': 20000}

# %% [markdown]
# ### Logistic Regression Coefficients

# %%
weights = eli5.show_weights(estimator = logreg_grid.best_estimator_.named_steps['logisticregression'], 
                            feature_names = logreg_grid.best_estimator_.named_steps['columntransformer'].get_feature_names_out(), 
                            top=15,
                            target_names = {0: '1940s', 1: '1950s', 2: '1960s', 3: '1970s', 4: '1980s', 5: '1990s', 6: '2000s', 7: '2010s'})
weights.data = weights.data.replace('background-color:', 'color:black; background-color:')
weights
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights-wrapper" style="border-collapse: collapse; border: none; margin-bottom: 1.5em;">
#             <tr>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=1940s
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=1950s
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=1960s
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=1970s
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=1980s
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=1990s
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=2000s
#
# </b>
#
# top features
#                     </td>
#
#                     <td style="padding: 0.5em; border: 1px solid black; text-align: center;">
#                         <b>
#
#         y=2010s
#
# </b>
#
# top features
#                     </td>
#
#             </tr>
#             <tr>
#
#
#                         <td style="padding: 0px; border: 1px solid black; vertical-align: top;">
#
#
#
#
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; width: 100%;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="color:black; background-color: hsl(120, 100.00%, 84.66%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.491
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="color:black; background-color: hsl(120, 100.00%, 96.06%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.501
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dead
#     </td>
#
# </tr>
#
#             <tr style="color:black; background-color: hsl(120, 100.00%, 96.27%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.462
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         soon
#     </td>
#
# </tr>
#
#             <tr style="color:black; background-color: hsl(120, 100.00%, 96.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.443
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         trip
#     </td>
#
# </tr>
#
#             <tr style="color:black; background-color: hsl(120, 100.00%, 96.47%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.428
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         park
#     </td>
#
# </tr>
#
#             <tr style="color:black; background-color: hsl(120, 100.00%, 96.48%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.425
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         fear
#     </td>
#
# </tr>
#
#
#             <tr style="color:black; background-color: hsl(120, 100.00%, 96.48%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 342 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="color:black; background-color: hsl(0, 100.00%, 96.49%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 647 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="color:black; background-color: hsl(0, 100.00%, 96.49%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.425
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         wind
#     </td>
#
# </tr>
#
#             <tr style="color:black; background-color: hsl(0, 100.00%, 96.47%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.428
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         john
#     </td>
#
# </tr>
#
#             <tr style="color:black; background-color: hsl(0, 100.00%, 96.43%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.435
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         close
#     </td>
#
# </tr>
#
#             <tr style="color:black; background-color: hsl(0, 100.00%, 96.43%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.436
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         feel
#     </td>
#
# </tr>
#
#             <tr style="color:black; background-color: hsl(0, 100.00%, 96.40%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.439
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         hold
#     </td>
#
# </tr>
#
#             <tr style="color:black; background-color: hsl(0, 100.00%, 96.30%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.457
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         left
#     </td>
#
# </tr>
#
#             <tr style="color:black; background-color: hsl(0, 100.00%, 96.26%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.464
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         baby
#     </td>
#
# </tr>
#
#             <tr style="color:black; background-color: hsl(0, 100.00%, 95.41%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.623
#     </td>
#     <

# %% [markdown]
# ## Attempt 3 - Random Forests

# %%
# creating pipe with naive bayes and countvectorizer
ct1 = make_column_transformer(
    (CountVectorizer(stop_words = 'english', max_features = 750), 'clean_lyrics'),
    remainder='passthrough',
    verbose_feature_names_out = False)

forest_pipe = make_pipeline(ct1, StandardScaler(with_mean = False), RandomForestClassifier(random_state = 48))

# gridsearching across ngram ranges
params = {}

# creating gridsearch and fitting to training data
forest_grid = GridSearchCV(forest_pipe, params, n_jobs =-1)
forest_grid.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('countvectorizer',
#                                                                          CountVectorizer(max_features=750,
#                                                                                          stop_words='english'),
#                                                                          'clean_lyrics')],
#                                                           verbose_feature_names_out=False)),
#                                        ('standardscaler',
#                                         StandardScaler(with_mean=False)),
#                                        ('randomforestclassifier',
#                                         RandomForestClassifier(random_state=48))]),
#              n_jobs=-1, param_grid={})

# %%
forest_grid.get_params()
# Out:
# {'cv': None,
#  'error_score': nan,
#  'estimator__memory': None,
#  'estimator__steps': [('columntransformer',
#    ColumnTransformer(remainder='passthrough',
#                      transformers=[('countvectorizer',
#                                     CountVectorizer(max_features=750,
#                                                     stop_words='english'),
#                                     'clean_lyrics')],
#                      verbose_feature_names_out=False)),
#   ('standardscaler', StandardScaler(with_mean=False)),
#   ('randomforestclassifier', RandomForestClassifier(random_state=48))],
#  'estimator__verbose': False,
#  'estimator__columntransformer': ColumnTransformer(remainder='passthrough',
#                    transformers=[('countvectorizer',
#                                   CountVectorizer(max_features=750,
#                                                   stop_words='english'),
#                                   'clean_lyrics')],
#                    verbose_feature_names_out=False),
#  'estimator__standardscaler': StandardScaler(with_mean=False),
#  'estimator__randomforestclassifier': RandomForestClassifier(random_state=48),
#  'estimator__columntransformer__n_jobs': None,
#  'estimator__columntransformer__remainder': 'passthrough',
#  'estimator__columntransformer__sparse_threshold': 0.3,
#  'estimator__columntransformer__transformer_weights': None,
#  'estimator__columntransformer__transformers': [('countvectorizer',
#    CountVectorizer(max_features=750, stop_words='english'),
#    'clean_lyrics')],
#  'estimator__columntransformer__verbose': False,
#  'estimator__columntransformer__verbose_feature_names_out': False,
#  'estimator__columntransformer__countvectorizer': CountVectorizer(max_features=750, stop_words='english'),
#  'estimator__columntransformer__countvectorizer__analyzer': 'word',
#  'estimator__columntransformer__countvectorizer__binary': False,
#  'estimator__columntransformer__countvectorizer__decode_error': 'strict',
#  'estimator__columntransformer__countvectorizer__dtype': numpy.int64,
#  'estimator__columntransformer__countvectorizer__encoding': 'utf-8',
#  'estimator__columntransformer__countvectorizer__input': 'content',
#  'estimator__columntransformer__countvectorizer__lowercase': True,
#  'estimator__columntransformer__countvectorizer__max_df': 1.0,
#  'estimator__columntransformer__countvectorizer__max_features': 750,
#  'estimator__columntransformer__countvectorizer__min_df': 1,
#  'estimator__columntransformer__countvectorizer__ngram_range': (1, 1),
#  'estimator__columntransformer__countvectorizer__preprocessor': None,
#  'estimator__columntransformer__countvectorizer__stop_words': 'english',
#  'estimator__columntransformer__countvectorizer__strip_accents': None,
#  'estimator__columntransformer__countvectorizer__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'estimator__columntransformer__countvectorizer__tokenizer': None,
#  'estimator__columntransformer__countvectorizer__vocabulary': None,
#  'estimator__standardscaler__copy': True,
#  'estimator__standardscaler__with_mean': False,
#  'estimator__standardscaler__with_std': True,
#  'estimator__randomforestclassifier__bootstrap': True,
#  'estimator__randomforestclassifier__ccp_alpha': 0.0,
#  'estimator__randomforestclassifier__class_weight': None,
#  'estimator__randomforestclassifier__criterion': 'gini',
#  'estimator__randomforestclassifier__max_depth': None,
#  'estimator__randomforestclassifier__max_features': 'auto',
#  'estimator__randomforestclassifier__max_leaf_nodes': None,
#  'estimator__randomforestclassifier__max_samples': None,
#  'estimator__randomforestclassifier__min_impurity_decrease': 0.0,
#  'estimator__randomforestclassifier__min_samples_leaf': 1,
#  'estimator__randomforestclassifier__min_samples_split': 2,
#  'estimator__randomforestclassifier__min_weight_fraction_leaf': 0.0,
#  'estimator__randomforestclassifier__n_estimators': 100,
#  'estimator__randomforestclassifier__n_jobs': None,
#  'estimator__randomforestclassifier__oob_score': False,
#  'estimator__randomforestclassifier__random_state': 48,
#  'estimator__randomforestclassifier__verbose': 0,
#  'estimator__randomforestclassifier__warm_start': False,
#  'estimator': Pipeline(steps=[('columntransformer',
#                   ColumnTransformer(remainder='passthrough',
#                                     transformers=[('countvectorizer',
#                                                    CountVectorizer(max_features=750,
#                                                                    stop_words='english'),
#                                                    'clean_lyrics')],
#                                     verbose_feature_names_out=False)),
#                  ('standardscaler', StandardScaler(with_mean=False)),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(random_state=48))]),
#  'n_jobs': -1,
#  'param_grid': {},
#  'pre_dispatch': '2*n_jobs',
#  'refit': True,
#  'return_train_score': False,
#  'scoring': None,
#  'verbose': 0}

# %%
# creating predictions from training data
preds = forest_grid.predict(X_test)

# accuracy score on test set
forest_grid.score(X_test, y_test)

# %%
# accuracy score on training set
forest_grid.score(X_train, y_train)
# Out:
# 0.9995032290114257

# %%
# pulling best parameters from gridsearch
forest_grid.best_params_
# Out:
# {}

# %%
forest_grid.best_estimator_
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('countvectorizer',
#                                                   CountVectorizer(max_features=750,
#                                                                   stop_words='english'),
#                                                   'clean_lyrics')],
#                                    verbose_feature_names_out=False)),
#                 ('standardscaler', StandardScaler(with_mean=False)),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(random_state=48))])

# %% [markdown]
# ### Random Forest Weights

# %%
weights = eli5.show_weights(estimator = forest_grid.best_estimator_.named_steps['randomforestclassifier'], 
                            feature_names = forest_grid.best_estimator_.named_steps['columntransformer'].get_feature_names_out(), 
                            top=25,
                            target_names = {0: '1940s', 1: '1950s', 2: '1960s', 3: '1970s', 4: '1980s', 5: '1990s', 6: '2000s', 7: '2010s'})
weights.data = weights.data.replace('background-color:', 'color:black; background-color:')
weights
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="color:black; background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0422
#
#                     &plusmn; 0.0268
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 word_count
#             </td>
#         </tr>
#
#         <tr style="color:black; background-color: hsl(120, 100.00%, 91.73%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0120
#
#                     &plusmn; 0.0069
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 know
#             </td>
#         </tr>
#
#         <tr style="color:black; background-color: hsl(120, 100.00%, 91.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0115
#
#                     &plusmn; 0.0056
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 love
#             </td>
#         </tr>
#
#         <tr style="color:black; background-color: hsl(120, 100.00%, 92.62%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0102
#
#                     &plusmn; 0.0078
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 like
#             </td>
#         </tr>
#
#         <tr style="color:black; background-color: hsl(120, 100.00%, 93.26%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0089
#
#                     &plusmn; 0.0051
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 oh
#             </td>
#         </tr>
#
#         <tr style="color:black; background-color: hsl(120, 100.00%, 93.45%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0086
#
#                     &plusmn; 0.0055
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 yeah
#             </td>
#         </tr>
#
#         <tr style="color:black; background-color: hsl(120, 100.00%, 93.60%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0083
#
#                     &plusmn; 0.0049
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 time
#             </td>
#         </tr>
#
#         <tr style="color:black; background-color: hsl(120, 100.00%, 93.75%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0080
#
#                     &plusmn; 0.0064
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 cause
#             </td>
#         </tr>
#
#         <tr style="color:black; background-color: hsl(120, 100.00%, 93.86%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0078
#
#                     &plusmn; 0.0053
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 baby
#             </td>
#         </tr>
#
#         <tr style="color:black; background-color: hsl(120, 100.00%, 93.87%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0078
#
#                     &plusmn; 0.0098
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 wanna
#             </td>
#         </tr>
#
#         <tr style="color:black; background-color: hsl(120, 100.00%, 93.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0077
#
#                     &plusmn; 0.0051
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 got
#             </td>
#         </tr>
#
#         <tr style="color:black; background-color: hsl(120, 100.00%, 94.06%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0075
#
#                     &plusmn; 0.0051
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 make
#             </td>
#         </tr>
#
#         <tr style="color:black; background-color: hsl(120, 100.00%, 94.08%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0074
#
#                     &plusmn; 0.0049
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ll
#             </td>
#         </tr>
#
#         <tr style="color:black; background-color: hsl(120, 100.00%, 94.20%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0072
#
#                     &plusmn; 0.0053
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 want
#             </td>
#         </tr>
#
#         <tr style="color:black; background-color: hsl(120, 100.00%, 94.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0068
#
#                     &plusmn; 0.0051
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 girl
#             </td>
#         </tr>
#
#         <tr style="color:black; background-color: hsl(120, 100.00%, 94.43%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0068
#
#                     &plusmn; 0.0041
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 heart
#             </td>
#         </tr>
#
#         <tr style="color:black; background-color: hsl(120, 100.00%, 94.44%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0068
#
#                     &plusmn; 0.0043
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 say
#             </td>
#         </tr>
#
#         <tr style="color:black; background-color: hsl(120, 100.00%, 94.44%); border: none;">
#             <td style="padding: 0

# %% [markdown]
# ## Attempt 4 - Gradient Boosting Classifier

# %%
# creating pipe with naive bayes and countvectorizer
ct1 = make_column_transformer(
    (CountVectorizer(stop_words = 'english', max_features = 750), 'clean_lyrics'),
    remainder='passthrough',
    verbose_feature_names_out = False)

boost_pipe = make_pipeline(ct1, StandardScaler(with_mean = False), GradientBoostingClassifier(random_state = 48))

# gridsearching across ngram ranges
params = {}

# creating gridsearch and fitting to training data
boost_grid = GridSearchCV(boost_pipe, params, n_jobs =-1)
boost_grid.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('countvectorizer',
#                                                                          CountVectorizer(max_features=750,
#                                                                                          stop_words='english'),
#                                                                          'clean_lyrics')],
#                                                           verbose_feature_names_out=False)),
#                                        ('standardscaler',
#                                         StandardScaler(with_mean=False)),
#                                        ('gradientboostingclassifier',
#                                         GradientBoostingClassifier(random_state=48))]),
#              n_jobs=-1, param_grid={})

# %%
# creating predictions from training data
preds = boost_grid.predict(X_test)

# accuracy score on test set
boost_grid.score(X_test, y_test)
# Out:
# 0.37453462397617276

# %%
# accuracy score on training set
boost_grid.score(X_train, y_train)
# Out:
# 0.7560854446100348
